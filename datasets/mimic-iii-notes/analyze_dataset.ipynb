# %%
import pandas as pd

# %%
ds_df = pd.read_json('NOTES_len6K_src5900_cov0.5_w_ESGs_test_split.jsonl', lines=True)

# %%
ds_df
# Out:
#       example_id                                             source  \
# 0    19322119378  Sinus rhythm. {{Low limb lead voltage}}. {{Pri...
# 1    20091116425  Sinus rhythm Possible {{anterior infarct}} - a...
# 2    12169107757  Sinus rhythm, without {{diagnostic abnormality...
# 3    19738102287  Sinus rhythm. {{Left ventricular hypertrophy}}...
# 4     7758102646  2:07 PM CHEST PORTABLE AP Clip # Reason: {{che...
# ..           ...                                                ...
# 261  77815103081  10:53 AM CAROT CEREB Clip # Reason: {{Stent as...
# 262  30660107310  {{Baseline artifact}}. Sinus rhythm. {{Low lim...
# 263  31245109216  Patient admitted from OSH in NY. She has PMH o...
# 264  57507108029  Sinus rhythm. {{Diffuse ST segment elevation}}...
# 265  25724107008  Sinus rhythm. Consider {{left atrial abnormali...
#
#                                                 target  len_source  \
# 0    Patient is a 62 year-old male with metastatic ...       10092
# ...

# %%
# Max len_tgt_length in test split.
max(set(ds_df['len_tgt_tok']))
# Out:
# 1774
